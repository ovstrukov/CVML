# %% [markdown]
# # Dogs vs Cats

# %% [markdown]
# https://www.kaggle.com/c/dogs-vs-cats-redux-kernels-edition

# %%
import cv2
import numpy as np
import tensorflow as tf
from tensorflow.keras.applications import vgg16

print(tf.__version__)
print(tf.executing_eagerly())
# Out:
# 2.7.0
# True

# %% [markdown]
# ## Функции загрузки данных

# %%
import os
from random import shuffle
from glob import glob

IMG_SIZE = (224, 224)  # размер входного изображения сети

train_files = glob('data/train_sample/*.jpg')
test_files = glob('data/test_sample/*.jpg')

# загружаем входное изображение и предобрабатываем
def load_image(path, target_size=IMG_SIZE):
    img = cv2.imread(path)[...,::-1]
    img = cv2.resize(img, target_size)
    return vgg16.preprocess_input(img)  # предобработка для VGG16

# функция-генератор загрузки обучающих данных с диска
def fit_generator(files, batch_size=32):
    batch_size = min(batch_size, len(files))
    while True:
        shuffle(files)
        for k in range(len(files) // batch_size):
            i = k * batch_size
            j = i + batch_size
            if j > len(files):
                j = - j % len(files)
            x = np.array([load_image(path) for path in files[i:j]])
            y = np.array([1. if os.path.basename(path).startswith('dog') else 0.
                          for path in files[i:j]])
            yield (x, y)

# функция-генератор загрузки тестовых изображений с диска
def predict_generator(files):
    while True:
        for path in files:
            yield np.array([load_image(path)])

# %% [markdown]
# ## Визуализируем примеры для обучения

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
fig = plt.figure(figsize=(16, 8))
for i, path in enumerate(train_files[:10], 1):
    subplot = fig.add_subplot(2, 5, i)
    subplot.set_title('%s' % path.split('/')[-1])
    img = cv2.imread(path)[...,::-1]
    img = cv2.resize(img, IMG_SIZE)
    plt.imshow(img)

# %% [markdown]
# ## Загружаем предобученную модель

# %%
# base_model - объект класса keras.models.Model (Functional Model)
base_model = vgg16.VGG16(weights='imagenet',
                         include_top=False,
                         input_shape=(IMG_SIZE[0], IMG_SIZE[1], 3))

# %%
base_model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Добавляем полносвязный слой

# %%
# фиксируем все веса предобученной сети
for layer in base_model.layers:
    layer.trainable = False

x = base_model.layers[-5].output
x = tf.keras.layers.GlobalAveragePooling2D()(x)
x = tf.keras.layers.BatchNormalization()(x)
x = tf.keras.layers.Dense(1,  # один выход (бинарная классификация)
                          activation='sigmoid',  # функция активации  
                          kernel_regularizer=tf.keras.regularizers.l1(1e-4))(x)

model = tf.keras.Model(inputs=base_model.input, outputs=x, name='dogs_vs_cats')

# %% [markdown]
# ## Выводим архитектуру модели

# %%
model.summary()
# Out:
# Model: "dogs_vs_cats"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  global_average_pooling2d_1   (None, 512)              0
#  (GlobalAveragePooling2D)
#
#  batch_normalization_1 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dense_1 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 7,637,825
# Trainable params: 1,537
# Non-trainable params: 7,636,288
# _________________________________________________________________

# %% [markdown]
# ## Компилируем модель и запускаем обучение

# %%
model.compile(optimizer='adam', 
              loss='binary_crossentropy',  # функция потерь binary_crossentropy (log loss
              metrics=['accuracy'])

# %%
val_samples = 5  # число изображений в валидационной выборке

shuffle(train_files)  # перемешиваем обучающую выборку
validation_data = next(fit_generator(train_files[:val_samples], val_samples))
train_data = fit_generator(train_files[val_samples:])  # данные читаем функцией-генератором

# запускаем процесс обучения
model.fit(train_data,
          steps_per_epoch=10,  # число вызовов генератора за эпоху
          epochs=100,  # число эпох обучения
          validation_data=validation_data)
# Out:
# Epoch 1/100
# 10/10 [==============================] - 19s 2s/step - loss: 0.6882 - accuracy: 0.5813 - val_loss: 0.3931 - val_accuracy: 0.8000
# Epoch 2/100
# 10/10 [==============================] - 21s 2s/step - loss: 0.6239 - accuracy: 0.6875 - val_loss: 0.4809 - val_accuracy: 0.8000
# Epoch 3/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.5349 - accuracy: 0.7531 - val_loss: 0.3497 - val_accuracy: 0.8000
# Epoch 4/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.4114 - accuracy: 0.8375 - val_loss: 0.3327 - val_accuracy: 0.8000
# Epoch 5/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.4508 - accuracy: 0.7781 - val_loss: 0.3350 - val_accuracy: 0.8000
# Epoch 6/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.3785 - accuracy: 0.8250 - val_loss: 0.3072 - val_accuracy: 0.8000
# Epoch 7/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.3730 - accuracy: 0.8438 - val_loss: 0.3117 - val_accuracy: 0.8000
# Epoch 8/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.3665 - accuracy: 0.8406 - val_loss: 0.2890 - val_accuracy: 0.8000
# Epoch 9/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.3138 - accuracy: 0.8750 - val_loss: 0.2734 - val_accuracy: 0.8000
# Epoch 10/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.3290 - accuracy: 0.8531 - val_loss: 0.2614 - val_accuracy: 0.8000
# Epoch 11/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.3136 - accuracy: 0.8656 - val_loss: 0.2491 - val_accuracy: 1.0000
# Epoch 12/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.3121 - accuracy: 0.8625 - val_loss: 0.2461 - val_accuracy: 0.8000
# Epoch 13/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.2608 - accuracy: 0.9031 - val_loss: 0.2584 - val_accuracy: 0.8000
# Epoch 14/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.2600 - accuracy: 0.9031 - val_loss: 0.2627 - val_accuracy: 0.8000
# Epoch 15/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.3105 - accuracy: 0.8750 - val_loss: 0.2170 - val_accuracy: 1.0000
# Epoch 16/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.3159 - accuracy: 0.8813 - val_loss: 0.1967 - val_accuracy: 1.0000
# Epoch 17/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.2938 - accuracy: 0.8813 - val_loss: 0.1837 - val_accuracy: 1.0000
# Epoch 18/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.2898 - accuracy: 0.8813 - val_loss: 0.1992 - val_accuracy: 1.0000
# Epoch 19/100
# 10/10 [==============================] - 23s 2s/step - loss: 0.2722 - accuracy: 0.9000 - val_loss: 0.2146 - val_accuracy: 1.0000
# Epoch 20/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.2720 - accuracy: 0.9000 - val_loss: 0.2079 - val_accuracy: 1.0000
# Epoch 21/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.2591 - accuracy: 0.9031 - val_loss: 0.2155 - val_accuracy: 1.0000
# Epoch 22/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.2261 - accuracy: 0.9219 - val_loss: 0.2239 - val_accuracy: 0.8000
# Epoch 23/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.2318 - accuracy: 0.9031 - val_loss: 0.1897 - val_accuracy: 1.0000
# Epoch 24/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.2332 - accuracy: 0.9094 - val_loss: 0.1630 - val_accuracy: 1.0000
# Epoch 25/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.1958 - accuracy: 0.9500 - val_loss: 0.1532 - val_accuracy: 1.0000
# Epoch 26/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.2236 - accuracy: 0.9281 - val_loss: 0.1553 - val_accuracy: 1.0000
# Epoch 27/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.2052 - accuracy: 0.9250 - val_loss: 0.1859 - val_accuracy: 1.0000
# Epoch 28/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.2079 - accuracy: 0.9250 - val_loss: 0.2365 - val_accuracy: 0.8000
# Epoch 29/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.2733 - accuracy: 0.8813 - val_loss: 0.2062 - val_accuracy: 1.0000
# Epoch 30/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.2293 - accuracy: 0.9125 - val_loss: 0.1910 - val_accuracy: 1.0000
# Epoch 31/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.2297 - accuracy: 0.9031 - val_loss: 0.1980 - val_accuracy: 1.0000
# Epoch 32/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.2389 - accuracy: 0.9187 - val_loss: 0.1981 - val_accuracy: 0.8000
# Epoch 33/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.1867 - accuracy: 0.9156 - val_loss: 0.1580 - val_accuracy: 1.0000
# Epoch 34/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.1586 - accuracy: 0.9375 - val_loss: 0.1543 - val_accuracy: 1.0000
# Epoch 35/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.2026 - accuracy: 0.9250 - val_loss: 0.1499 - val_accuracy: 1.0000
# Epoch 36/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.2055 - accuracy: 0.9219 - val_loss: 0.1640 - val_accuracy: 1.0000
# Epoch 37/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.2020 - accuracy: 0.9187 - val_loss: 0.1890 - val_accuracy: 0.8000
# Epoch 38/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.2358 - accuracy: 0.8969 - val_loss: 0.1584 - val_accuracy: 1.0000
# Epoch 39/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.1950 - accuracy: 0.9219 - val_loss: 0.1389 - val_accuracy: 1.0000
# Epoch 40/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.2163 - accuracy: 0.9094 - val_loss: 0.1448 - val_accuracy: 1.0000
# Epoch 41/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.1847 - accuracy: 0.9281 - val_loss: 0.1216 - val_accuracy: 1.0000
# Epoch 42/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.1746 - accuracy: 0.9344 - val_loss: 0.1124 - val_accuracy: 1.0000
# Epoch 43/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.1637 - accuracy: 0.9406 - val_loss: 0.1278 - val_accuracy: 1.0000
# Epoch 44/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.1717 - accuracy: 0.9281 - val_loss: 0.1337 - val_accuracy: 1.0000
# Epoch 45/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.2026 - accuracy: 0.9219 - val_loss: 0.1467 - val_accuracy: 1.0000
# Epoch 46/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.2160 - accuracy: 0.9062 - val_loss: 0.1624 - val_accuracy: 1.0000
# Epoch 47/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.2139 - accuracy: 0.9281 - val_loss: 0.1665 - val_accuracy: 1.0000
# Epoch 48/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.2071 - accuracy: 0.9094 - val_loss: 0.1176 - val_accuracy: 1.0000
# Epoch 49/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.1748 - accuracy: 0.9344 - val_loss: 0.1111 - val_accuracy: 1.0000
# Epoch 50/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.1619 - accuracy: 0.9500 - val_loss: 0.1091 - val_accuracy: 1.0000
# Epoch 51/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.2339 - accuracy: 0.9219 - val_loss: 0.1427 - val_accuracy: 1.0000
# Epoch 52/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.1780 - accuracy: 0.9250 - val_loss: 0.1507 - val_accuracy: 1.0000
# Epoch 53/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.1613 - accuracy: 0.9312 - val_loss: 0.1964 - val_accuracy: 0.8000
# Epoch 54/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.1185 - accuracy: 0.9594 - val_loss: 0.1613 - val_accuracy: 1.0000
# Epoch 55/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.1399 - accuracy: 0.9563 - val_loss: 0.1418 - val_accuracy: 1.0000
# Epoch 56/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.1595 - accuracy: 0.9438 - val_loss: 0.1121 - val_accuracy: 1.0000
# Epoch 57/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.1405 - accuracy: 0.9563 - val_loss: 0.1161 - val_accuracy: 1.0000
# Epoch 58/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.1730 - accuracy: 0.9375 - val_loss: 0.1386 - val_accuracy: 1.0000
# Epoch 59/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.1896 - accuracy: 0.9187 - val_loss: 0.1421 - val_accuracy: 1.0000
# Epoch 60/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.1707 - accuracy: 0.9438 - val_loss: 0.1355 - val_accuracy: 1.0000
# Epoch 61/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.1539 - accuracy: 0.9344 - val_loss: 0.1111 - val_accuracy: 1.0000
# Epoch 62/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.1670 - accuracy: 0.9438 - val_loss: 0.1123 - val_accuracy: 1.0000
# Epoch 63/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.1624 - accuracy: 0.9250 - val_loss: 0.1131 - val_accuracy: 1.0000
# Epoch 64/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.1774 - accuracy: 0.9312 - val_loss: 0.1085 - val_accuracy: 1.0000
# Epoch 65/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.2041 - accuracy: 0.9094 - val_loss: 0.1157 - val_accuracy: 1.0000
# Epoch 66/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.1792 - accuracy: 0.9312 - val_loss: 0.1291 - val_accuracy: 1.0000
# Epoch 67/100
# 10/10 [==============================] - 21s 2s/step - loss: 0.1535 - accuracy: 0.9375 - val_loss: 0.1063 - val_accuracy: 1.0000
# Epoch 68/100
# 10/10 [==============================] - 21s 2s/step - loss: 0.1428 - accuracy: 0.9531 - val_loss: 0.1171 - val_accuracy: 1.0000
# Epoch 69/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.1110 - accuracy: 0.9563 - val_loss: 0.1294 - val_accuracy: 1.0000
# Epoch 70/100
# 10/10 [==============================] - 21s 2s/step - loss: 0.1723 - accuracy: 0.9250 - val_loss: 0.1366 - val_accuracy: 1.0000
# Epoch 71/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.1737 - accuracy: 0.9219 - val_loss: 0.1051 - val_accuracy: 1.0000
# Epoch 72/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.1515 - accuracy: 0.9344 - val_loss: 0.1055 - val_accuracy: 1.0000
# Epoch 73/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.1354 - accuracy: 0.9312 - val_loss: 0.1099 - val_accuracy: 1.0000
# Epoch 74/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.1492 - accuracy: 0.9500 - val_loss: 0.1301 - val_accuracy: 1.0000
# Epoch 75/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.1309 - accuracy: 0.9531 - val_loss: 0.1860 - val_accuracy: 0.8000
# Epoch 76/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.1596 - accuracy: 0.9406 - val_loss: 0.1093 - val_accuracy: 1.0000
# Epoch 77/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.1430 - accuracy: 0.9500 - val_loss: 0.0869 - val_accuracy: 1.0000
# Epoch 78/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.1414 - accuracy: 0.9563 - val_loss: 0.0988 - val_accuracy: 1.0000
# Epoch 79/100
# 10/10 [==============================] - 21s 2s/step - loss: 0.1857 - accuracy: 0.9406 - val_loss: 0.1207 - val_accuracy: 1.0000
# Epoch 80/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.1488 - accuracy: 0.9500 - val_loss: 0.0990 - val_accuracy: 1.0000
# Epoch 81/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.1487 - accuracy: 0.9406 - val_loss: 0.0965 - val_accuracy: 1.0000
# Epoch 82/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.1070 - accuracy: 0.9656 - val_loss: 0.1429 - val_accuracy: 1.0000
# Epoch 83/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.1454 - accuracy: 0.9469 - val_loss: 0.1932 - val_accuracy: 0.8000
# Epoch 84/100
# 10/10 [==============================] - 21s 2s/step - loss: 0.1078 - accuracy: 0.9781 - val_loss: 0.2223 - val_accuracy: 0.8000
# Epoch 85/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.2137 - accuracy: 0.9156 - val_loss: 0.1423 - val_accuracy: 1.0000
# Epoch 86/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.1335 - accuracy: 0.9500 - val_loss: 0.1074 - val_accuracy: 1.0000
# Epoch 87/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.1475 - accuracy: 0.9469 - val_loss: 0.0855 - val_accuracy: 1.0000
# Epoch 88/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.1508 - accuracy: 0.9312 - val_loss: 0.0932 - val_accuracy: 1.0000
# Epoch 89/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.1605 - accuracy: 0.9344 - val_loss: 0.1148 - val_accuracy: 1.0000
# Epoch 90/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.1340 - accuracy: 0.9500 - val_loss: 0.1512 - val_accuracy: 1.0000
# Epoch 91/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.2182 - accuracy: 0.9219 - val_loss: 0.1228 - val_accuracy: 1.0000
# Epoch 92/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.1222 - accuracy: 0.9594 - val_loss: 0.1382 - val_accuracy: 1.0000
# Epoch 93/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.1401 - accuracy: 0.9469 - val_loss: 0.1294 - val_accuracy: 1.0000
# Epoch 94/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.1630 - accuracy: 0.9312 - val_loss: 0.1054 - val_accuracy: 1.0000
# Epoch 95/100
# 10/10 [==============================] - 21s 2s/step - loss: 0.1522 - accuracy: 0.9563 - val_loss: 0.0780 - val_accuracy: 1.0000
# Epoch 96/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.1682 - accuracy: 0.9469 - val_loss: 0.0846 - val_accuracy: 1.0000
# Epoch 97/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.1494 - accuracy: 0.9500 - val_loss: 0.1102 - val_accuracy: 1.0000
# Epoch 98/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.1379 - accuracy: 0.9406 - val_loss: 0.1058 - val_accuracy: 1.0000
# Epoch 99/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.1428 - accuracy: 0.9531 - val_loss: 0.0977 - val_accuracy: 1.0000
# Epoch 100/100
# 10/10 [==============================] - 22s 2s/step - loss: 0.1547 - accuracy: 0.9344 - val_loss: 0.0830 - val_accuracy: 1.0000

# %%
model.save('cats-dogs-vgg16Strukov.hdf5')

# %% [markdown]
# ## Предсказания на проверочной выборке

# %%
test_pred = model.predict(
    predict_generator(test_files), steps=len(test_files))

# %%
fig = plt.figure(figsize=(16, 8))
for i, (path, score) in enumerate(zip(test_files[:10], test_pred[:10]), 1):
    subplot = fig.add_subplot(2, 5, i)
    subplot.set_title('%.2f %s' % (score, os.path.basename(path)))
    img = cv2.imread(path)[...,::-1]
    img = cv2.resize(img, IMG_SIZE)
    subplot.imshow(img)

# %% [markdown]
# ## Готовим данные для отправки

# %%
import re

with open('submit.txt', 'w') as dst:
    dst.write('id,label\n')
    for path, score in zip(test_files, test_pred):
        dst.write('%s,%f\n' % (re.search('(\d+).jpg$', path).group(1), score))

# %%
import re
import csv

with open('submit.csv', 'w', newline='') as dst:
    fieldnames = ['id', 'label']
    writer = csv.DictWriter(dst, fieldnames=fieldnames)
    writer.writeheader()
    for path, score in zip(test_files, test_pred):
        writer.writerow({'id': re.search('(\d+).jpg$', path).group(1), 'label':float(score)})

# %%
# LogLoss = 0.14664
